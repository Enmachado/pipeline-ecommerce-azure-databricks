# %%
spark.conf.set("SUA_CHAVE_AQUI")

display(dbutils.fs.ls("SUA_CHAVE_AQUI"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <command-6162661725426551>, line 1
# ----> 1 spark.conf.set("SUA_CHAVE_AQUI")
#       3 display(dbutils.fs.ls("SUA_CHAVE_AQUI"))
#
# TypeError: RuntimeConf.set() missing 1 required positional argument: 'value'
